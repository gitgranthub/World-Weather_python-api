# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# %matplotlib inline

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import date
import os
import scipy.stats as sts
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# %%
# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count

len(cities)
# Out:
# 628

# %%
#create intitial dataframe to hold cities
#cities_df = pd.DataFrame(cities, columns = ['city_name'])

# %%
#add additional columns to dataframes
#cities_df['weather'] = ""
#cities_df.head()

# %% [markdown]
# ### Perform API Calls

# %% [markdown]
# * Perform a weather check on each city using a series of successive API calls.
#
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
#query_url = f"{url}appid={api_key}&units={units}&q="
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# set up lists to hold reponse info
#temp cities for testing
#cities = ["Sheboygan", "Chicago", "Miami"]
#city_id = []

# %%
#counter for city numbers
counter = 1

#variables for weather data frame
city_name = []
lat = []
long = []
temp_imperial = []
humidity = []
cloudiness = []
wind_speed = []

print('Beginning City Data Retrieval')
print('------------------------------')
# Loop through the list of cities and perform a request for data on each
for city in cities:
    
    try:
        #city = str.title()
        response = requests.get(query_url + city).json()
        city_name.append(response['name'])
        lat.append(response['coord']['lat'])
        long.append(response['coord']['lon'])
        temp_imperial.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        #print result city
        print(f'Processing Record #{counter} of #{len(cities)} initial results | {city}')
        #set counter
        counter = counter + 1
    except (KeyError, IndexError):
        print(f"City data for record #{counter} not found. Skipping...")
        counter = counter


#("city")str.title()
print('------------------------------')
print(f"End of City Data Retrieval. Total Weather Records Retrieved from original {len(cities)} is {counter}")
print('------------------------------')
# Out:
# Beginning City Data Retrieval
# ------------------------------
# Processing Record #1 of #628 initial results | busselton
# Processing Record #2 of #628 initial results | ascension
# City data for record #3 not found. Skipping...
# Processing Record #3 of #628 initial results | huarmey
# Processing Record #4 of #628 initial results | bitung
# Processing Record #5 of #628 initial results | faanui
# Processing Record #6 of #628 initial results | gat
# City data for record #7 not found. Skipping...
# Processing Record #7 of #628 initial results | santa helena de goias
# Processing Record #8 of #628 initial results | la romana
# Processing Record #9 of #628 initial results | jalu
# Processing Record #10 of #628 initial results | vaini
# City data for record #11 not found. Skipping...
# Processing Record #11 of #628 initial results | provideniya
# City data for record #12 not found. Skipping...
# Processing Record #12 of #628 initial results | oranjestad
# Processing Record #13 of #628 initial results | beisfjord
# Processing Record #14 of #628 initial results | orocue
# Processing Record #15 of #628 initial results | aksarka
# Processing Record #16 of #628 initial results | east london
# Processing Record #17 of #628 initial results | lakshmipur
# City data for record #18 not found. Skipping...
# Processing Record #18 of #628 initial results | aksu
# Processing Record #19 of #628 initial results | portobelo
# Processing Record #20 of #628 initial results | albany
# Processing Record #21 of #628 initial results | mar del plata
# Processing Record #22 of #628 initial results | truro
# Processing Record #23 of #628 initial results | ushuaia
# Processing Record #24 of #628 initial results | lata
# Processing Record #25 of #628 initial results | cape town
# Processing Record #26 of #628 initial results | sinnamary
# Processing Record #27 of #628 initial results | zlobin
# Processing Record #28 of #628 initial results | mersing
# City data for record #29 not found. Skipping...
# Processing Record #29 of #628 initial results | valenza
# Processing Record #30 of #628 initial results | hermanus
# Processing Record #31 of #628 initial results | qaanaaq
# Processing Record #32 of #628 initial results | puerto ayora
# Processing Record #33 of #628 initial results | torbay
# Processing Record #34 of #628 initial results | cambridge
# Processing Record #35 of #628 initial results | najran
# Processing Record #36 of #628 initial results | avarua
# Processing Record #37 of #628 initial results | bogorodskoye
# Processing Record #237 of #628 initial results | calabasas
# Processing Record #238 of #628 initial results | caravelas
# Processing Record #239 of #628 initial results | cordoba
# City data for record #240 not found. Skipping...
# Processing Record #240 of #628 initial results | sao raimundo das mangabeiras
# Processing Record #241 of #628 initial results | rio gallegos
# Processing Record #242 of #628 initial results | pozo colorado
# Processing Record #243 of #628 initial results | ust-kulom
# Processing Record #244 of #628 initial results | tongchuan
# Processing Record #245 of #628 initial results | perbaungan
# Processing Record #246 of #628 initial results | belawan
# Processing Record #247 of #628 initial results | skibbereen
# Processing Record #248 of #628 initial results | ozuluama
# Processing Record #249 of #628 initial results | stokmarknes
# Processing Record #250 of #628 initial results | richards bay
# Processing Record #251 of #628 initial results | camacupa
# Processing Record #252 of #628 initial results | gladstone
# Processing Record #253 of #628 initial results | sitka
# Processing Record #254 of #628 initial results | qaqortoq
# Processing Record #255 of #628 initial results | santa vitoria do palmar
# Processing Record #256 of #628 initial results | fort nelson
# Processing Record #257 of #628 initial results | cayenne
# Processing Record #258 of #628 initial results | wattegama
# Processing Record #259 of #628 initial results | tayoltita
# Processing Record #260 of #628 initial results | kharp
# Processing Record #261 of #628 initial results | ventspils
# Processing Record #262 of #628 initial results | alcaniz
# Processing Record #263 of #628 initial results | bambous virieux
# Processing Record #264 of #628 initial results | gorontalo
# Processing Record #265 of #628 initial results | baruun-urt
# Processing Record #266 of #628 initial results | makakilo city
# Processing Record #267 of #628 initial results | gardez
# Processing Record #268 of #628 initial results | grand bank
# Processing Record #269 of #628 initial results | cap-aux-meules
# Processing Record #270 of #628 initial results | srandakan
# Processing Record #271 of #628 initial results | awjilah
# Processing Record #272 of #628 initial results | kodiak
# Processing Record #273 of #628 initial results | puerto cabezas
# Processing Record #274 of #628 initial results | atlantic city
# Processing Record #275 of #628 initial results | villa bruzual
# Processing Record #276 of #628 initial results | cairns
# Processing Record #277 of #628 initial results | te anau
# Processing Record #278 of #628 initial results | ivanteyevka
# Processing Record #279 of #628 initial results | warrnambool
# Processing Record #280 of #628 initial results | kapuskasing
# Processing Record #281 of #628 initial results | saint-philippe
# Processing Record #282 of #628 initial results | meghri
# Processing Record #283 of #628 initial results | fare
# Processing Record #284 of #628 initial results | port blair
# Processing Record #285 of #628 initial results | sao miguel do araguaia
# Processing Record #286 of #628 initial results | kununurra
# Processing Record #287 of #628 initial results | kingisepp
# Processing Record #288 of #628 initial results | tynda
# Processing Record #289 of #628 initial results | fairbanks
# Processing Record #290 of #628 initial results | geraldton
# City data for record #291 not found. Skipping...
# Processing Record #291 of #628 initial results | balabac
# Processing Record #292 of #628 initial results | bathsheba
# Processing Record #293 of #628 initial results | bonthe
# Processing Record #294 of #628 initial results | skjervoy
# Processing Record #295 of #628 initial results | umm lajj
# Processing Record #296 of #628 initial results | lexington park
# Processing Record #297 of #628 initial results | severo-kurilsk
# Processing Record #298 of #628 initial results | kulhudhuffushi
# Processing Record #299 of #628 initial results | rawson
# City data for record #300 not found. Skipping...
# Processing Record #300 of #628 initial results | malakal
# Processing Record #301 of #628 initial results | clyde river
# City data for record #302 not found. Skipping...
# Processing Record #302 of #628 initial results | kenai
# Processing Record #303 of #628 initial results | klerksdorp
# Processing Record #304 of #628 initial results | longyearbyen
# Processing Record #305 of #628 initial results | verin
# Processing Record #306 of #628 initial results | lufilufi
# Processing Record #307 of #628 initial results | kalabo
# Processing Record #308 of #628 initial results | tecoanapa
# Processing Record #309 of #628 initial results | vuktyl
# Processing Record #310 of #628 initial results | japura
# Processing Record #311 of #628 initial results | ponta delgada
# Processing Record #312 of #628 initial results | san cristobal
# Processing Record #313 of #628 initial results | kabalo
# Processing Record #314 of #628 initial results | sisimiut
# Processing Record #315 of #628 initial results | xam nua
# Processing Record #316 of #628 initial results | conceicao do araguaia
# Processing Record #317 of #628 initial results | iroquois falls
# Processing Record #318 of #628 initial results | bracciano
# Processing Record #319 of #628 initial results | varkaus
# Processing Record #320 of #628 initial results | baherden
# Processing Record #321 of #628 initial results | shimoda
# Processing Record #322 of #628 initial results | asau
# Processing Record #323 of #628 initial results | esperance
# Processing Record #324 of #628 initial results | ucluelet
# Processing Record #325 of #628 initial results | aksum
# Processing Record #326 of #628 initial results | jacksonville
# City data for record #327 not found. Skipping...
# Processing Record #327 of #628 initial results | half moon bay
# City data for record #328 not found. Skipping...
# Processing Record #328 of #628 initial results | tazovskiy
# Processing Record #329 of #628 initial results | fez
# Processing Record #330 of #628 initial results | stephenville
# Processing Record #331 of #628 initial results | egvekinot
# Processing Record #332 of #628 initial results | kahului
# Processing Record #333 of #628 initial results | porto de moz
# Processing Record #334 of #628 initial results | orlik
# Processing Record #335 of #628 initial results | stolin
# City data for record #336 not found. Skipping...
# Processing Record #336 of #628 initial results | pinega
# Processing Record #337 of #628 initial results | pochutla
# Processing Record #338 of #628 initial results | anshun
# Processing Record #339 of #628 initial results | kushmurun
# Processing Record #340 of #628 initial results | ternate
# Processing Record #341 of #628 initial results | barcelona
# Processing Record #342 of #628 initial results | carrick-on-suir
# Processing Record #343 of #628 initial results | sri aman
# Processing Record #344 of #628 initial results | sivas
# Processing Record #345 of #628 initial results | angoche
# Processing Record #346 of #628 initial results | pacific grove
# Processing Record #347 of #628 initial results | bilma
# Processing Record #348 of #628 initial results | fairview
# Processing Record #349 of #628 initial results | det udom
# Processing Record #350 of #628 initial results | ladario
# Processing Record #351 of #628 initial results | nome
# Processing Record #352 of #628 initial results | henties bay
# Processing Record #353 of #628 initial results | scarborough
# Processing Record #354 of #628 initial results | dossor
# City data for record #355 not found. Skipping...
# Processing Record #355 of #628 initial results | harper
# Processing Record #356 of #628 initial results | lodja
# Processing Record #357 of #628 initial results | ambon
# Processing Record #358 of #628 initial results | ciudad bolivar
# City data for record #359 not found. Skipping...
# Processing Record #359 of #628 initial results | tsevie
# Processing Record #360 of #628 initial results | quelimane
# Processing Record #361 of #628 initial results | salto
# Processing Record #362 of #628 initial results | kudahuvadhoo
# Processing Record #363 of #628 initial results | burley
# Processing Record #364 of #628 initial results | prince albert
# Processing Record #365 of #628 initial results | kualakapuas
# Processing Record #366 of #628 initial results | sehwan
# Processing Record #367 of #628 initial results | larap
# Processing Record #368 of #628 initial results | chernyshevskiy
# City data for record #369 not found. Skipping...
# Processing Record #369 of #628 initial results | nikolskoye
# Processing Record #370 of #628 initial results | kysyl-syr
# Processing Record #371 of #628 initial results | roald
# Processing Record #372 of #628 initial results | hay river
# Processing Record #373 of #628 initial results | haines junction
# Processing Record #374 of #628 initial results | amuntai
# Processing Record #375 of #628 initial results | sao joao da barra
# Processing Record #376 of #628 initial results | hornepayne
# Processing Record #377 of #628 initial results | monduli
# Processing Record #378 of #628 initial results | kautokeino
# Processing Record #379 of #628 initial results | kramat
# Processing Record #380 of #628 initial results | salmo
# Processing Record #381 of #628 initial results | tambovka
# Processing Record #382 of #628 initial results | arman
# Processing Record #383 of #628 initial results | valkeakoski
# Processing Record #384 of #628 initial results | porbandar
# Processing Record #385 of #628 initial results | wiwili
# Processing Record #386 of #628 initial results | eureka
# Processing Record #387 of #628 initial results | palmer
# City data for record #388 not found. Skipping...
# Processing Record #388 of #628 initial results | vanavara
# Processing Record #389 of #628 initial results | sakaraha
# Processing Record #390 of #628 initial results | cururupu
# Processing Record #391 of #628 initial results | rocky mountain house
# Processing Record #392 of #628 initial results | portland
# Processing Record #393 of #628 initial results | port lincoln
# Processing Record #394 of #628 initial results | srednekolymsk
# Processing Record #395 of #628 initial results | kalevala
# Processing Record #396 of #628 initial results | kahramanmaras
# Processing Record #397 of #628 initial results | bubaque
# Processing Record #398 of #628 initial results | helena
# Processing Record #399 of #628 initial results | krasnoselkup
# Processing Record #400 of #628 initial results | la rioja
# Processing Record #401 of #628 initial results | kilindoni
# Processing Record #402 of #628 initial results | kapoeta
# Processing Record #403 of #628 initial results | astoria
# Processing Record #404 of #628 initial results | tarabuco
# Processing Record #405 of #628 initial results | isangel
# City data for record #406 not found. Skipping...
# Processing Record #406 of #628 initial results | kyren
# Processing Record #407 of #628 initial results | katangli
# Processing Record #408 of #628 initial results | diffa
# Processing Record #409 of #628 initial results | nazret
# Processing Record #410 of #628 initial results | pancas
# Processing Record #411 of #628 initial results | yongan
# Processing Record #412 of #628 initial results | emerald
# Processing Record #413 of #628 initial results | bourail
# Processing Record #414 of #628 initial results | bhanjanagar
# Processing Record #415 of #628 initial results | beroroha
# Processing Record #416 of #628 initial results | qandala
# Processing Record #417 of #628 initial results | virginia beach
# Processing Record #418 of #628 initial results | valdivia
# Processing Record #419 of #628 initial results | yulara
# Processing Record #420 of #628 initial results | chapais
# Processing Record #421 of #628 initial results | merauke
# Processing Record #422 of #628 initial results | halifax
# Processing Record #423 of #628 initial results | gatton
# Processing Record #424 of #628 initial results | vung tau
# Processing Record #425 of #628 initial results | obo
# Processing Record #426 of #628 initial results | dawlatabad
# Processing Record #427 of #628 initial results | monte alegre
# Processing Record #428 of #628 initial results | mezhova
# City data for record #429 not found. Skipping...
# Processing Record #429 of #628 initial results | mazyr
# Processing Record #430 of #628 initial results | fukaya
# Processing Record #431 of #628 initial results | saint-raymond
# Processing Record #432 of #628 initial results | avera
# Processing Record #433 of #628 initial results | iquitos
# Processing Record #434 of #628 initial results | lebu
# Processing Record #435 of #628 initial results | pozzallo
# Processing Record #436 of #628 initial results | kurilsk
# Processing Record #437 of #628 initial results | port moresby
# Processing Record #438 of #628 initial results | antalaha
# City data for record #439 not found. Skipping...
# Processing Record #439 of #628 initial results | hobyo
# City data for record #440 not found. Skipping...
# Processing Record #440 of #628 initial results | verkhniy avzyan
# Processing Record #441 of #628 initial results | vega de alatorre
# Processing Record #442 of #628 initial results | fray bentos
# Processing Record #443 of #628 initial results | yarkovo
# Processing Record #444 of #628 initial results | luanda
# Processing Record #445 of #628 initial results | khorramshahr
# Processing Record #446 of #628 initial results | bafut
# Processing Record #447 of #628 initial results | sayyan
# Processing Record #448 of #628 initial results | sandovo
# City data for record #449 not found. Skipping...
# Processing Record #449 of #628 initial results | santa isabel
# Processing Record #450 of #628 initial results | dejen
# Processing Record #451 of #628 initial results | posse
# Processing Record #452 of #628 initial results | shiyan
# Processing Record #453 of #628 initial results | kalmunai
# Processing Record #454 of #628 initial results | acoyapa
# Processing Record #455 of #628 initial results | saint anthony
# Processing Record #456 of #628 initial results | beloha
# Processing Record #457 of #628 initial results | maumere
# City data for record #458 not found. Skipping...
# City data for record #458 not found. Skipping...
# Processing Record #458 of #628 initial results | constitucion
# Processing Record #459 of #628 initial results | luderitz
# Processing Record #460 of #628 initial results | verkhnyaya sinyachikha
# Processing Record #461 of #628 initial results | the valley
# Processing Record #462 of #628 initial results | rehoboth
# City data for record #463 not found. Skipping...
# Processing Record #463 of #628 initial results | sydney
# Processing Record #464 of #628 initial results | yecla
# Processing Record #465 of #628 initial results | launceston
# Processing Record #466 of #628 initial results | sanmenxia
# Processing Record #467 of #628 initial results | clarence town
# Processing Record #468 of #628 initial results | barreirinhas
# Processing Record #469 of #628 initial results | bardiyah
# Processing Record #470 of #628 initial results | snasa
# Processing Record #471 of #628 initial results | recco
# Processing Record #472 of #628 initial results | hambantota
# Processing Record #473 of #628 initial results | kinkala
# Processing Record #474 of #628 initial results | chiredzi
# Processing Record #475 of #628 initial results | vavuniya
# Processing Record #476 of #628 initial results | alihe
# Processing Record #477 of #628 initial results | qinhuangdao
# Processing Record #478 of #628 initial results | chaohu
# Processing Record #479 of #628 initial results | kyra
# Processing Record #480 of #628 initial results | svetlyy
# Processing Record #481 of #628 initial results | coihaique
# Processing Record #482 of #628 initial results | satipo
# Processing Record #483 of #628 initial results | brunico
# Processing Record #484 of #628 initial results | san vicente
# Processing Record #485 of #628 initial results | shengjin
# Processing Record #486 of #628 initial results | acapulco
# City data for record #487 not found. Skipping...
# City data for record #487 not found. Skipping...
# Processing Record #487 of #628 initial results | meulaboh
# Processing Record #488 of #628 initial results | rabo de peixe
# Processing Record #489 of #628 initial results | basoko
# Processing Record #490 of #628 initial results | karaman
# Processing Record #491 of #628 initial results | escanaba
# Processing Record #492 of #628 initial results | aklavik
# Processing Record #493 of #628 initial results | den helder
# Processing Record #494 of #628 initial results | bela
# Processing Record #495 of #628 initial results | contamana
# Processing Record #496 of #628 initial results | kidal
# Processing Record #497 of #628 initial results | vao
# Processing Record #498 of #628 initial results | tateyama
# Processing Record #499 of #628 initial results | saint-pierre
# Processing Record #500 of #628 initial results | lang son
# Processing Record #501 of #628 initial results | dunedin
# Processing Record #502 of #628 initial results | bulgan
# Processing Record #503 of #628 initial results | port macquarie
# City data for record #504 not found. Skipping...
# Processing Record #504 of #628 initial results | noyabrsk
# Processing Record #505 of #628 initial results | svetlogorsk
# Processing Record #506 of #628 initial results | cabedelo
# Processing Record #507 of #628 initial results | haimen
# Processing Record #508 of #628 initial results | saryozek
# Processing Record #509 of #628 initial results | mayumba
# Processing Record #510 of #628 initial results | zeliezovce
# Processing Record #511 of #628 initial results | palora
# Processing Record #512 of #628 initial results | lichinga
# Processing Record #513 of #628 initial results | high level
# Processing Record #514 of #628 initial results | naze
# Processing Record #515 of #628 initial results | paita
# Processing Record #516 of #628 initial results | souillac
# Processing Record #517 of #628 initial results | ambilobe
# Processing Record #518 of #628 initial results | taonan
# City data for record #519 not found. Skipping...
# Processing Record #519 of #628 initial results | acajutla
# Processing Record #520 of #628 initial results | gurupi
# Processing Record #521 of #628 initial results | elizabeth city
# Processing Record #522 of #628 initial results | poum
# Processing Record #523 of #628 initial results | jibuti
# Processing Record #524 of #628 initial results | biak
# Processing Record #525 of #628 initial results | palana
# City data for record #526 not found. Skipping...
# Processing Record #526 of #628 initial results | bud
# Processing Record #527 of #628 initial results | atar
# Processing Record #528 of #628 initial results | cap malheureux
# Processing Record #529 of #628 initial results | odessa
# Processing Record #530 of #628 initial results | gwanda
# Processing Record #531 of #628 initial results | rio rancho
# Processing Record #532 of #628 initial results | litovko
# Processing Record #533 of #628 initial results | shakawe
# Processing Record #534 of #628 initial results | yumen
# Processing Record #535 of #628 initial results | iisalmi
# Processing Record #536 of #628 initial results | shu
# Processing Record #537 of #628 initial results | sola
# Processing Record #538 of #628 initial results | alzamay
# Processing Record #539 of #628 initial results | ashland
# Processing Record #540 of #628 initial results | bilibino
# Processing Record #541 of #628 initial results | churapcha
# Processing Record #542 of #628 initial results | whitehorse
# City data for record #543 not found. Skipping...
# Processing Record #543 of #628 initial results | dwarka
# Processing Record #544 of #628 initial results | ust-maya
# Processing Record #545 of #628 initial results | santa maria
# Processing Record #546 of #628 initial results | morondava
# Processing Record #547 of #628 initial results | nizhnevartovsk
# Processing Record #548 of #628 initial results | santiago del estero
# Processing Record #549 of #628 initial results | chokwe
# Processing Record #550 of #628 initial results | igrim
# Processing Record #551 of #628 initial results | cockburn town
# Processing Record #552 of #628 initial results | chone
# Processing Record #553 of #628 initial results | touros
# Processing Record #554 of #628 initial results | sibu
# Processing Record #555 of #628 initial results | saint-joseph
# Processing Record #556 of #628 initial results | banda aceh
# Processing Record #557 of #628 initial results | dryden
# Processing Record #558 of #628 initial results | riberalta
# Processing Record #559 of #628 initial results | san roque
# Processing Record #560 of #628 initial results | raudeberg
# Processing Record #561 of #628 initial results | evanston
# Processing Record #562 of #628 initial results | alto araguaia
# Processing Record #563 of #628 initial results | bongandanga
# Processing Record #564 of #628 initial results | marzuq
# Processing Record #565 of #628 initial results | lloydminster
# Processing Record #566 of #628 initial results | megion
# Processing Record #567 of #628 initial results | kamena vourla
# Processing Record #568 of #628 initial results | fonte boa
# Processing Record #569 of #628 initial results | havre-saint-pierre
# Processing Record #570 of #628 initial results | crato
# Processing Record #571 of #628 initial results | moju
# Processing Record #572 of #628 initial results | el coyote
# Processing Record #573 of #628 initial results | chara
# Processing Record #574 of #628 initial results | pangody
# Processing Record #575 of #628 initial results | marsh harbour
# Processing Record #576 of #628 initial results | zabid
# Processing Record #577 of #628 initial results | coos bay
# ------------------------------
# End of City Data Retrieval. Total Weather Records Retrieved from original 628 is 578
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame

# %%
city_data_df = pd.DataFrame({'City': city_name,
                            'Latitude': lat,
                            'Longitude': long,
                            'Temp': temp_imperial,
                            'Humidity': humidity,
                            'Cloudiness': cloudiness,
                            'Wind Speed': wind_speed
                            })

# %% [markdown]
# * Export the city data into a .csv.

# %%
pd.DataFrame.to_csv(city_data_df, '../output_data/city_weather_data.csv')

# %% [markdown]
# * Display the DataFrame

# %%
city_data_df.head()
# Out:
#         City  Latitude  Longitude   Temp  Humidity  Cloudiness  Wind Speed
# 0  Busselton    -33.65     115.33  55.92        73           7       13.91
# 1  Ascension     30.22     -90.90  78.19        83          34        4.03
# 2    Huarmey    -10.07     -78.15  59.61        85          10        9.08
# 3     Bitung      1.45     125.18  87.80        66          20        2.24
# 4     Faanui    -16.48    -151.75  77.05        83          99       17.78

# %%
len(city_data_df)
# Out:
# 577

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#Get the indices of cities that have humidity over 100%.
#checking for High Humidity Cities and confirming visually
city_data_h_humid = city_data_df[city_data_df['Humidity'] > 99]
city_data_h_humid
# Out:
#                     City  Latitude  Longitude   Temp  Humidity  Cloudiness  \
# 21                 Truro     50.27      -5.05  57.52       100          90
# 32                Torbay     47.67     -52.73  49.12       100          90
# 49              Klaksvík     62.23      -6.59  48.20       100          93
# 62                Hasaki     35.73     140.83  66.07       100          75
# 66   Gemeente Wageningen     51.97       5.67  57.79       100          20
# 107            Sistranda     63.73       8.83  53.29       100          75
# 221              Belfast     54.58      -5.93  54.52       100         100
# 227             Katsuura     35.13     140.30  69.60       100          75
# 240         Río Gallegos    -51.62     -69.22  35.60       100          90
# 246           Skibbereen     51.55      -9.27  57.20       100          90
# 256              Cayenne      4.93     -52.33  75.20       100          99
# 257            Wattegama      6.80      81.48  77.00       100          20
# 260            Ventspils     57.39      21.56  46.40       100           3
# 318              Varkaus     62.32      27.87  59.23       100           2
# 320              Shimoda     34.67     138.95  67.30       100          75
# 343       Sivas Province     39.79      37.00  51.80       100           0
# 417             Valdivia    -39.81     -73.25  50.00       100          90
# 449                Dejen     10.17      38.13  52.38       100         100
# 471           Hambantota      6.12      81.12  77.00       100          20
# 477               Chaohu     31.60     117.87  78.80       100          90
# 497             Tateyama     34.98     139.87  70.56       100          75
# 505             Cabedelo     -6.98     -34.83  73.40       100          75
# 524               Palana     59.12     159.97  45.99       100         100
# 552               Touros     -5.20     -35.46  73.40       100          75
#
#      Wind Speed
# 21        10.29
# 32        12.75
# 49        14.99
# 62         8.05
# 66         2.24
# 107        5.82
# 221        4.70
# 227        8.05
# 240        9.17
# 246       12.75
# 256        9.48
# 257        1.12
# 260        2.24
# 318        1.12
# 320        6.93
# 343        2.24
# 417        6.93
# 449        3.58
# 471        1.12
# 477       15.66
# 497        8.05
# 505        8.05
# 524       16.67
# 552        4.70

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
#Dropping rows of the High Humidity Cities if they exist and confirming the database count is lower.
clean_city_data = city_data_df.drop(city_data_df[city_data_df['Humidity'] > 99].index, inplace = False)
len(clean_city_data)
# Out:
# 553

# %%
# Extract relevant fields from the data frame
clean_city_data.reset_index(drop=True, inplace=True)
clean_city_data
# Out:
#               City  Latitude  Longitude   Temp  Humidity  Cloudiness  \
# 0        Busselton    -33.65     115.33  55.92        73           7
# 1        Ascension     30.22     -90.90  78.19        83          34
# 2          Huarmey    -10.07     -78.15  59.61        85          10
# 3           Bitung      1.45     125.18  87.80        66          20
# 4           Faanui    -16.48    -151.75  77.05        83          99
# ..             ...       ...        ...    ...       ...         ...
# 548          Chara     56.91     118.26  56.88        80         100
# 549        Pangody     65.85      74.49  53.78        85         100
# 550  Marsh Harbour     26.54     -77.06  82.78        80         100
# 551          Zabid     14.20      43.32  90.75        36          95
# 552       Coos Bay     43.37    -124.22  61.70        77           1
#
#      Wind Speed
# 0         13.91
# 1          4.03
# 2          9.08
# 3          2.24
# 4         17.78
# ..          ...
# 548        2.73
# 549       10.71
# 550       17.54
# 551        3.11
# 552       24.16
#
# [553 rows x 7 columns]

# %%
# Export the City_Data into a csv
pd.DataFrame.to_csv(clean_city_data, '../output_data/clean_city_data.csv')

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
#
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#I perfer to drop the alpha a bit. The overlay of the plots display a nice density.
plt.scatter(clean_city_data['Latitude'], clean_city_data['Temp'],
            marker="o", s=50, facecolors='#E99202', edgecolors='#754901', alpha=0.6)
plt.title(f"City Latitude vs. Temperature ({date.today()})", fontsize=14)
plt.xlabel("Latitude", fontsize=12)
plt.ylabel("Temp (F)", fontsize=12)
plt.grid(True)
plt.savefig('../images/lat_temp.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(clean_city_data['Latitude'], clean_city_data['Humidity'],
            marker="o", s=50, facecolors='#027886', edgecolors='#003036', alpha=0.6)
plt.title(f"City Latitude vs. Humidity ({date.today()})", fontsize=14)
plt.xlabel("Latitude", fontsize=12)
plt.ylabel("Humidity (%)", fontsize=12)
plt.grid(True)
plt.savefig('../images/lat_humidity.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(clean_city_data['Latitude'], clean_city_data['Cloudiness'],
            marker="o", s=50, facecolors='#9DA5B9', edgecolors='#575C69', alpha=0.8)
plt.title(f"City Latitude vs. Cloudiness ({date.today()})", fontsize=14)
plt.xlabel("Latitude", fontsize=12)
plt.ylabel("Cloudiness", fontsize=12)
plt.grid(True)
plt.savefig('../images/lat_clouds.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(clean_city_data['Latitude'], clean_city_data['Wind Speed'],
            marker="o", s=50, facecolors='#33747C', edgecolors='#1B3C40', alpha=0.8)
plt.title(f"City Latitude vs. Wind Speed ({date.today()})", fontsize=14)
plt.xlabel("Latitude", fontsize=12)
plt.ylabel("Wind Speed (mph)", fontsize=12)
plt.grid(True)
plt.savefig('../images/lat_wind.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Linear Regression Latitude vs. Temperature Plot

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Calculate the correlation coefficient and linear regression model 
lat_line = clean_city_data.iloc[:,1]
humidity_lin = clean_city_data.iloc[:,4]
correlation = sts.pearsonr(lat_line,humidity_lin)

#sets a variable for using '\n' in printed 'fstring'
nreturn = '\n'

x_values = clean_city_data['Latitude']
y_values = clean_city_data['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.title(f"City Latitude vs. Humidity ({date.today()})", fontsize=14)
plt.xlabel("Latitude", fontsize=12)
plt.ylabel("Humidity (%)", fontsize=12)
plt.grid(True)
#plt.tight_layout()
plt.scatter(x_values,y_values, marker="o", s=50, facecolors='#027886', edgecolors="#003036", alpha=0.6)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The correlation between Latitude {nreturn}and Humidity is {round(correlation[0],2)}")

plt.savefig("../images/lat_humidity_lin_regress.png", bbox_inches = 'tight', dpi=100)
plt.show()
# Out:
# The correlation between Latitude
# and Humidity is -0.01

# %% [markdown]
# # Create Northern and Southern Hemisphere DataFrames

# %%
#Southern Latitude Database creation
slat_city_data = clean_city_data.drop(clean_city_data[clean_city_data['Latitude'] >= 0].index, inplace = False)
len(slat_city_data)
# Out:
# 184

# %%
# Extract relevant fields from the southern lat dataframe
slat_city_data.reset_index(drop=True, inplace=True)
slat_city_data
# Out:
#                       City  Latitude  Longitude   Temp  Humidity  Cloudiness  \
# 0                Busselton    -33.65     115.33  55.92        73           7
# 1                  Huarmey    -10.07     -78.15  59.61        85          10
# 2                   Faanui    -16.48    -151.75  77.05        83          99
# 3    Santa Helena de Goiás    -17.81     -50.60  67.15        42           0
# 4                    Vaini    -21.20    -175.20  78.80        83          75
# ..                     ...       ...        ...    ...       ...         ...
# 179              Riberalta    -10.98     -66.10  75.25        54           0
# 180          Alto Araguaia    -17.31     -53.22  67.17        44           0
# 181              Fonte Boa     -2.50     -66.27  72.91        97         100
# 182                  Crato     -7.23     -39.41  70.02        73           0
# 183                   Moju     -1.88     -48.77  78.80        83          75
#
#      Wind Speed
# 0         13.91
# 1          9.08
# 2         17.78
# 3          2.59
# 4         11.41
# ..          ...
# 179        1.12
# 180        4.36
# 181        2.21
# 182       11.01
# 183        6.93
#
# [184 rows x 7 columns]

# %%
#Northern Latitude Database creation
nlat_city_data = clean_city_data.drop(clean_city_data[clean_city_data['Latitude'] <= 0].index, inplace = False)
len(nlat_city_data)
# Out:
# 369

# %%
# Extract relevant fields from the northern lat dataframe
nlat_city_data.reset_index(drop=True, inplace=True)
nlat_city_data
# Out:
#               City  Latitude  Longitude   Temp  Humidity  Cloudiness  \
# 0        Ascension     30.22     -90.90  78.19        83          34
# 1           Bitung      1.45     125.18  87.80        66          20
# 2       Kiryat Gat     31.61      34.76  70.66        84           1
# 3        La Romana     18.43     -68.97  77.00        94          75
# 4             Jalu     29.03      21.55  77.31        54           0
# ..             ...       ...        ...    ...       ...         ...
# 364          Chara     56.91     118.26  56.88        80         100
# 365        Pangody     65.85      74.49  53.78        85         100
# 366  Marsh Harbour     26.54     -77.06  82.78        80         100
# 367          Zabid     14.20      43.32  90.75        36          95
# 368       Coos Bay     43.37    -124.22  61.70        77           1
#
#      Wind Speed
# 0          4.03
# 1          2.24
# 2          6.53
# 3          4.70
# 4          6.82
# ..          ...
# 364        2.73
# 365       10.71
# 366       17.54
# 367        3.11
# 368       24.16
#
# [369 rows x 7 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
from scipy.stats import linregress
# Calculate the correlation coefficient and linear regression model 
lat_line = nlat_city_data.iloc[:,1]
temp_lin = nlat_city_data.iloc[:,3]
correlation = sts.pearsonr(lat_line,temp_lin)

#sets a variable for using '\n' in printed 'fstring'
nreturn = '\n'

x_values = nlat_city_data['Latitude']
y_values = nlat_city_data['Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.title(f"Northern Hemisphere City vs. Temperature ({date.today()})", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.ylabel("Temp (F)", fontsize=12)
plt.grid(True)
plt.scatter(x_values,y_values, marker="o", s=50, facecolors='#E99202', edgecolors="#754901", alpha=0.6)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
#plt.tight_layout()
print(f"The correlation between N. Hemisphere {nreturn}and Temperature is {round(correlation[0],2)}")

plt.savefig("../images/nhem_temp_lin_regress.png", bbox_inches = 'tight', dpi=150)
plt.show()
# Out:
# The correlation between N. Hemisphere
# and Temperature is -0.73

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
from scipy.stats import linregress
# Calculate the correlation coefficient and linear regression model 
lat_line = slat_city_data.iloc[:,1]
temp_lin = slat_city_data.iloc[:,3]
correlation = sts.pearsonr(lat_line,temp_lin)

#sets a variable for using '\n' in printed 'fstring'
nreturn = '\n'

x_values = slat_city_data['Latitude']
y_values = slat_city_data['Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.title(f"Southern Hemisphere City vs. Temperature ({date.today()})", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.ylabel("Temp (F)", fontsize=12)
plt.grid(True)
plt.scatter(x_values,y_values, marker="o", s=50, facecolors='#E99202', edgecolors="#754901", alpha=0.6)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
#plt.tight_layout()
print(f"The correlation between S. Hemisphere {nreturn}and Temperature is {round(correlation[0],2)}")

plt.savefig("../images/shem_temp_lin_regress.png", bbox_inches = 'tight', dpi=150)
plt.show()
# Out:
# The correlation between S. Hemisphere
# and Temperature is 0.76

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Calculate the correlation coefficient and linear regression model 
lat_line = nlat_city_data.iloc[:,1]
humidity_lin = nlat_city_data.iloc[:,4]
correlation = sts.pearsonr(lat_line,humidity_lin)

#sets a variable for using '\n' in printed 'fstring'
nreturn = '\n'

x_values = nlat_city_data['Latitude']
y_values = nlat_city_data['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.title(f"Northern Hemisphere City vs. Humidity ({date.today()})", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.ylabel("Humidity (%)", fontsize=12)
plt.grid(True)
plt.scatter(x_values,y_values, marker="o", s=50, facecolors='#027886', edgecolors="#003036", alpha=0.6)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
#plt.tight_layout()
print(f"The correlation between N. Hemisphere {nreturn}and Humidity is {round(correlation[0],2)}")

plt.savefig("../images/nhem_humidity_lin_regress.png", bbox_inches = 'tight', dpi=150)
plt.show()
# Out:
# The correlation between N. Hemisphere
# and Humidity is 0.01

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Calculate the correlation coefficient and linear regression model 
lat_line = slat_city_data.iloc[:,1]
humidity_lin = slat_city_data.iloc[:,4]
correlation = sts.pearsonr(lat_line,humidity_lin)

#sets a variable for using '\n' in printed 'fstring'
nreturn = '\n'

x_values = slat_city_data['Latitude']
y_values = slat_city_data['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.title(f"Southern Hemisphere City vs. Humidity ({date.today()})", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.ylabel("Humidity (%)", fontsize=12)
plt.grid(True)
plt.scatter(x_values,y_values, marker="o", s=50, facecolors='#027886', edgecolors="#003036", alpha=0.6)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
#plt.tight_layout()
print(f"The correlation between S. Hemisphere {nreturn}and Humidity is {round(correlation[0],2)}")

plt.savefig("../images/shem_humidity_lin_regress.png", bbox_inches = 'tight', dpi=150)
plt.show()
# Out:
# The correlation between S. Hemisphere
# and Humidity is 0.02

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Calculate the correlation coefficient and linear regression model 
lat_line = nlat_city_data.iloc[:,1]
cloud_lin = nlat_city_data.iloc[:,5]
correlation = sts.pearsonr(lat_line,cloud_lin)

#sets a variable for using '\n' in printed 'fstring'
nreturn = '\n'

x_values = nlat_city_data['Latitude']
y_values = nlat_city_data['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.title(f"Northern Hemisphere City vs. Cloudiness ({date.today()})", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.ylabel("Cloudiness", fontsize=12)
plt.grid(True)
plt.scatter(x_values,y_values, marker="o", s=50, facecolors='#9DA5B9', edgecolors="#575C69", alpha=0.6)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
#plt.tight_layout()
print(f"The correlation between N. Hemisphere {nreturn}and Cloudiness is {round(correlation[0],2)}")

plt.savefig("../images/nhem_cloudiness_regress.png", bbox_inches = 'tight', dpi=150)
plt.show()
# Out:
# The correlation between N. Hemisphere
# and Cloudiness is 0.1

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Calculate the correlation coefficient and linear regression model 
lat_line = slat_city_data.iloc[:,1]
cloud_lin = slat_city_data.iloc[:,5]
correlation = sts.pearsonr(lat_line,cloud_lin)

#sets a variable for using '\n' in printed 'fstring'
nreturn = '\n'

x_values = slat_city_data['Latitude']
y_values = slat_city_data['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.title(f"Southern Hemisphere City vs. Cloudiness ({date.today()})", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.ylabel("Cloudiness", fontsize=12)
plt.grid(True)
plt.scatter(x_values,y_values, marker="o", s=50, facecolors='#9DA5B9', edgecolors="#575C69", alpha=0.6)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
#plt.tight_layout()
print(f"The correlation between S. Hemisphere {nreturn}and Cloudiness is {round(correlation[0],2)}")

plt.savefig("../images/shem_cloudiness_regress.png", bbox_inches = 'tight', dpi=150)
plt.show()
# Out:
# The correlation between S. Hemisphere
# and Cloudiness is -0.05

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Calculate the correlation coefficient and linear regression model 
lat_line = nlat_city_data.iloc[:,1]
cloud_lin = nlat_city_data.iloc[:,6]
correlation = sts.pearsonr(lat_line,cloud_lin)

#sets a variable for using '\n' in printed 'fstring'
nreturn = '\n'

x_values = nlat_city_data['Latitude']
y_values = nlat_city_data['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.title(f"Northern Hemisphere City vs. Wind Speed ({date.today()})", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.ylabel("Wind Speed (mph)", fontsize=12)
plt.grid(True)
plt.scatter(x_values,y_values, marker="o", s=50, facecolors='#33747C', edgecolors='#1B3C40', alpha=0.6)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
#plt.tight_layout()
print(f"The correlation between N. Hemisphere {nreturn}and Wind Speed is {round(correlation[0],2)}")

plt.savefig("../images/nhem_wind_regress.png", bbox_inches = 'tight', dpi=150)
plt.show()
# Out:
# The correlation between N. Hemisphere
# and Wind Speed is 0.12

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Calculate the correlation coefficient and linear regression model 
lat_line = slat_city_data.iloc[:,1]
cloud_lin = slat_city_data.iloc[:,6]
correlation = sts.pearsonr(lat_line,cloud_lin)

#sets a variable for using '\n' in printed 'fstring'
nreturn = '\n'

x_values = slat_city_data['Latitude']
y_values = slat_city_data['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.title(f"Southern Hemisphere City vs. Wind Speed ({date.today()})", fontsize=12)
plt.xlabel("Latitude", fontsize=12)
plt.ylabel("Wind Speed (mph)", fontsize=12)
plt.grid(True)
plt.scatter(x_values,y_values, marker="o", s=50, facecolors='#33747C', edgecolors='#1B3C40', alpha=0.6)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
#plt.tight_layout()
print(f"The correlation between S. Hemisphere {nreturn}and Wind Speed is {round(correlation[0],2)}")

plt.savefig("../images/shem_wind_regress.png", bbox_inches = 'tight', dpi=150)
plt.show()
# Out:
# The correlation between S. Hemisphere
# and Wind Speed is -0.16
